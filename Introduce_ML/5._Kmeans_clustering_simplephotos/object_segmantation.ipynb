# %% [markdown]
# We have a picture, we need recognize the face and segment it out.
# Idea: the picture has 3 main colours, pink in lips and scarf, black in eyes, hair and background, white in skin.
# 3 colours - 3 clusters
# So we apply algorithm K-means clustering to segment pixels in picture into 3 clusters, then we chooes cluster, which is the face

# %% [markdown]
# This is a picture with 3 main colours: Red, Green and Blue.
# Each value also is a natural number that not exceeded 255.
# We consider each point be a vector 3 dimensionl vector and use algorithm K-means clustering

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

# Load picture
img = mpimg.imread('../asset/girl3.jpg')
plt.imshow(img)
imgplot = plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# Change picture to a matrix with each row means a pixel with 3 values of colour
X = img.reshape((img.shape[0]*img.shape[1], img.shape[2]))

# %%
# Image Compression (Image Compression and Data Compression in general)
for K in [2, 5, 10, 15, 20]:
    kmeans = KMeans(n_clusters=K).fit(X)
    label = kmeans.predict(X)

    img4 = np.zeros_like(X)
    # replace each pixel by its center
    for k in range(K):
        img4[label == k] = kmeans.cluster_centers_[k]
    # reshape and display output image
    img5 = img4.reshape((img.shape[0], img.shape[1], img.shape[2]))
    plt.imshow(img5, interpolation='nearest')
    plt.axis('off')
    plt.show()

# %%
for K in [3]:
    kmeans = KMeans(n_clusters=K).fit(X)
    label = kmeans.predict(X)

    img4 = np.zeros_like(X)
    # replace each pixel by its center
    for k in range(K):
        img4[label == k] = kmeans.cluster_centers_[k]
    # reshape and display output image
    img5 = img4.reshape((img.shape[0], img.shape[1], img.shape[2]))
    plt.imshow(img5, interpolation='nearest')
    plt.axis('off')
    plt.show()
